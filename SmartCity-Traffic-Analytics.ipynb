# %% [markdown]
# <a href="https://colab.research.google.com/github/git-mishrarushi/SmartCity-Traffic-Analytics/blob/main/SmartCity-Traffic-Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd66f4e6-c8f5-4355-8682-4c36c7e4860b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd66f4e6-c8f5-4355-8682-4c36c7e4860b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

delhi = pd.read_csv("delhi_traffic_cleaned.csv")
lucknow = pd.read_csv("lucknow_traffic_cleaned.csv")

delhi.head()
# Out:
#          Date  Hour            Location  Queue_Density  Stop_Density  \
# 0  2020-09-01     0       Mukarba Chowk             20            10
# 1  2020-09-02     1  ISBT Kashmere Gate             22            12
# 2  2020-09-03     2        Burari Chowk             24            12
# 3  2020-09-04     3        Ashram Chowk             23            14
# 4  2020-09-05     4       Mukarba Chowk             25            14
#
#    Accidents_Reported  Fatalities
# 0                   0           0
# 1                   1           1
# 2                   2           0
# 3                   3           1
# 4                   4           0

# %%
import pandas as pd

# Read both datasets
delhi = pd.read_csv("delhi_traffic_cleaned.csv")
lucknow = pd.read_csv("lucknow_traffic_cleaned.csv")

# Check first few rows
delhi.head(), lucknow.head()
# Out:
# (         Date  Hour            Location  Queue_Density  Stop_Density  \
#  0  2020-09-01     0       Mukarba Chowk             20            10
#  1  2020-09-02     1  ISBT Kashmere Gate             22            12
#  2  2020-09-03     2        Burari Chowk             24            12
#  3  2020-09-04     3        Ashram Chowk             23            14
#  4  2020-09-05     4       Mukarba Chowk             25            14
#
#     Accidents_Reported  Fatalities
#  0                   0           0
#  1                   1           1
#  2                   2           0
#  3                   3           1
#  4                   4           0  ,
#           Date  Hour     Location  Queue_Density  Stop_Density  \
#  0  2020-09-01     0   Hazratganj             15             8
#  1  2020-09-02     1     Alambagh             17            10
#  2  2020-09-03     2  Gomti Nagar             19            12
#  3  2020-09-04     3     Charbagh             21            11
# ...

# %%
# Peak traffic hours (Delhi)
delhi.groupby('Hour')['Queue_Density'].mean().plot(kind='bar', title="Delhi - Avg Queue Density by Hour")
# Out:
# <Axes: title={'center': 'Delhi - Avg Queue Density by Hour'}, xlabel='Hour'>
